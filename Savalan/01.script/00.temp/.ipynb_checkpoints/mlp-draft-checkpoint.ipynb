# %%
# %pip install progressbar xgboost matplotlib boto3 openpyxl tqdm hydroeval hydrotools

# %%
# hydrological packages
from hydrotools.nwm_client import utils 

# my packages
from evaluation_metric import MAPE, RMSE, KGE, PBias

# basic packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# system packages
from progressbar import ProgressBar
from datetime import datetime, date
import pickle
import warnings
warnings.filterwarnings("ignore")
import platform
import time

# data analysi packages
from scipy import optimize

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# deep learning packages
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
if platform.system() == 'Windows':
    onedrive_path = 'E:/OneDrive/OneDrive - The University of Alabama/10.material/01.data/usgs_data/'
    box_path = 'C:/Users/snaserneisary/Box/NWM-ML/'

elif platform.system() == 'Darwin':
    onedrive_path = '/Users/savalan/Library/CloudStorage/OneDrive-TheUniversityofAlabama/02.projects/03.ciroh/04.data/'
    box_path = '/Users/savalan/Library/CloudStorage/Box-Box/NWM-ML/Data/NWM/ut/'
    
elif platform.system() == 'Linux':
    path_01 = '/home/snaserneisary/01.projects/01.ciroh_p8/NWM-ML/Savalan/'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cpu

# %%
raw_training_data = pd.read_csv(path_01 + '03.output/raw_training_data.csv')
raw_training_data.pop('Unnamed: 0')
raw_training_data['station_id'] = raw_training_data['station_id'].astype('str')
raw_training_data.head()
# Out:
#   station_id        Lat        Long  Drainage_area_mi2  Mean_Basin_Elev_ft  \
# 0   10011500  40.965225 -110.853508              174.0              9720.0
# 1   10011500  40.965225 -110.853508              174.0              9720.0
# 2   10011500  40.965225 -110.853508              174.0              9720.0
# 3   10011500  40.965225 -110.853508              174.0              9720.0
# 4   10011500  40.965225 -110.853508              174.0              9720.0
#
#    Perc_Forest  Perc_Develop  Perc_Imperv  Perc_Herbace  Perc_Slop_30  ...  \
# 0         67.7           1.2         0.12          2.94          27.2  ...
# 1         67.7           1.2         0.12          2.94          27.2  ...
# 2         67.7           1.2         0.12          2.94          27.2  ...
# 3         67.7           1.2         0.12          2.94          27.2  ...
# 4         67.7           1.2         0.12          2.94          27.2  ...
#
#      datetime   flow_cfs        s1        s2  temperature_F  precipitation_in  \
# 0  2012-03-13  45.356945  0.515038  0.857167         35.096           0.00000
# 1  2012-03-14  49.750000  0.515038  0.857167         35.258           0.00000
# 2  2012-03-15  52.483334  0.515038  0.857167         36.860           0.00000
# 3  2012-03-16  60.296875  0.515038  0.857167         38.120           0.00000
# 4  2012-03-17  68.876045  0.515038  0.857167         38.102           0.04698
#
#    storage   swe  NWM_flow  DOY
# 0      0.0  7.70      60.0   73
# 1      0.0  7.45      62.0   74
# 2      0.0  7.35      65.0   75
# 3      0.0  7.25      63.0   76
# 4      0.0  6.85      65.0   77
#
# [5 rows x 21 columns]

# %%
Training_DF = raw_training_data.copy()

# %% [markdown]
# ### Editing the features based on the feature importance should be in the next cell!!!!!!!!!!!!!!!

# %%
# Editing the features based on the feature importance should be done here!!!!!!!!!!!!!!!

Training_DF.drop(['precipitation_in', 'temperature_F', 'Mean_Ann_Precip_in', 'Perc_Herbace', 'Perc_Forest',
                        'Mean_Basin_Elev_ft'], axis=1, inplace=True)

# %% [markdown]
# ### Remove headwater stations!!!!!!!

# %%
headwater_stations = ['10011500', '10109000', '10113500', '10128500', '10131000', '10146400', '10150500', '10154200',
'10172700', '10172800', '10172952']
Training_DF = Training_DF[~raw_training_data['station_id'].isin(headwater_stations)]

# %%
Training_DF.datetime = pd.to_datetime(Training_DF.datetime)
Training_DF.head()
# Out:
#     station_id        Lat        Long  Drainage_area_mi2  Perc_Develop  \
# 789   10126000  41.576321 -112.100782             7040.0          4.28
# 790   10126000  41.576321 -112.100782             7040.0          4.28
# 791   10126000  41.576321 -112.100782             7040.0          4.28
# 792   10126000  41.576321 -112.100782             7040.0          4.28
# 793   10126000  41.576321 -112.100782             7040.0          4.28
#
#      Perc_Imperv  Perc_Slop_30   datetime   flow_cfs        s1        s2  \
# 789         0.55          1.94 2012-03-01  1488.4375  0.515038  0.857167
# 790         0.55          1.94 2012-03-02  1282.1875  0.515038  0.857167
# 791         0.55          1.94 2012-03-03  1269.4791  0.515038  0.857167
# 792         0.55          1.94 2012-03-04  1551.5625  0.515038  0.857167
# 793         0.55          1.94 2012-03-05  1490.5209  0.515038  0.857167
#
#        storage        swe  NWM_flow  DOY
# 789  85.588235  12.778571    1542.0   61
# 790  86.712418  13.085714    1542.0   62
# 791  87.359477  13.178571    1542.0   63
# 792  88.163399  13.221429    1541.0   64
# 793  89.026144  13.221429    1541.0   65

# %%
x_train_temp = Training_DF[Training_DF.datetime < '01-01-2015']
x_train_temp.pop('station_id')
x_train_temp.pop('datetime')
y_train_temp = x_train_temp['flow_cfs']
x_train_temp.pop('flow_cfs')
x_train_temp.head()
# Out:
#            Lat        Long  Drainage_area_mi2  Perc_Develop  Perc_Imperv  \
# 789  41.576321 -112.100782             7040.0          4.28         0.55
# 790  41.576321 -112.100782             7040.0          4.28         0.55
# 791  41.576321 -112.100782             7040.0          4.28         0.55
# 792  41.576321 -112.100782             7040.0          4.28         0.55
# 793  41.576321 -112.100782             7040.0          4.28         0.55
#
#      Perc_Slop_30        s1        s2    storage        swe  NWM_flow  DOY
# 789          1.94  0.515038  0.857167  85.588235  12.778571    1542.0   61
# 790          1.94  0.515038  0.857167  86.712418  13.085714    1542.0   62
# 791          1.94  0.515038  0.857167  87.359477  13.178571    1542.0   63
# 792          1.94  0.515038  0.857167  88.163399  13.221429    1541.0   64
# 793          1.94  0.515038  0.857167  89.026144  13.221429    1541.0   65

# %%
# Scale the train inputs of the NN model
# First we need to convert it from pandas dataframe to a numpy array 
y_train = y_train_temp.to_numpy()
x_train = x_train_temp.to_numpy()
scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(x_train)
y_scaled_train = scaler.fit_transform(y_train.reshape(-1, 1))
y_scaled_train.shape
# Out:
# (8174, 1)

# %%
# Determining the test dataset. 
x_test_temp = Training_DF[Training_DF.datetime >= '01-01-2015']
x_test_temp.head()
# Out:
#     station_id        Lat        Long  Drainage_area_mi2  Perc_Develop  \
# 874   10126000  41.576321 -112.100782             7040.0          4.28
# 875   10126000  41.576321 -112.100782             7040.0          4.28
# 876   10126000  41.576321 -112.100782             7040.0          4.28
# 877   10126000  41.576321 -112.100782             7040.0          4.28
# 878   10126000  41.576321 -112.100782             7040.0          4.28
#
#      Perc_Imperv  Perc_Slop_30   datetime   flow_cfs        s1        s2  \
# 874         0.55          1.94 2015-03-01  723.29170  0.515038  0.857167
# 875         0.55          1.94 2015-03-02  742.03125  0.515038  0.857167
# 876         0.55          1.94 2015-03-03  729.18750  0.515038  0.857167
# 877         0.55          1.94 2015-03-04  792.37500  0.515038  0.857167
# 878         0.55          1.94 2015-03-05  848.16670  0.515038  0.857167
#
#        storage        swe  NWM_flow  DOY
# 874  79.712418  10.171429    1658.0   60
# 875  80.156863  10.185714    1668.0   61
# 876  80.620915  10.335714    1682.0   62
# 877  80.967320  10.564286    1701.0   63
# 878  81.320261  10.678571    1720.0   64

# %%
# Scale the test inputs of the NN model
# First we need to convert it from pandas dataframe to a numpy array 
x_test_temp_1 = x_test_temp.copy()
station_index_list = x_test_temp_1['station_id']
x_test_temp_1.pop('station_id')
x_test_temp_1.pop('datetime')
y_test_temp_1 = x_test_temp_1['flow_cfs']
x_test_temp_1.pop('flow_cfs')
x_test_1_np = x_test_temp_1.reset_index(drop=True).to_numpy()
y_test_1_np = y_test_temp_1.reset_index(drop=True).to_numpy()
x_test_1_scaled = scaler.fit_transform(x_test_1_np)
y_scaled_test_1 = scaler.fit_transform(y_test_1_np.reshape(-1, 1))

# %%
# MLP

n_targets = 1
tries = 10
cri_temp_nse = np.zeros([3, n_targets, tries])
cri_temp_rmse = np.zeros([3, n_targets, tries])
cri_temp_r2 = np.zeros([3, n_targets, tries])
cri_temp_kge = np.zeros([3, n_targets, tries])
cri_temp_lognse = np.zeros([3, n_targets, tries])
print('finish')
# Out:
# finish

# %%
# Reshape input for MLP model
x_train_scaled_test = torch.Tensor(x_train_scaled)
y_train_scaled_test = torch.Tensor(y_scaled_train)
print('test shape', x_train_scaled_test.shape)
print('train shape', y_train_scaled_test.shape)
# Out:
# test shape torch.Size([8174, 12])
# train shape torch.Size([8174, 1])

# %%
# Take data to the proper device (GPU or CPU)
# x_train_scaled_test = x_train_scaled_test.to(device)
# y_train_scaled_test = y_train_scaled_test.to(device)

# %%
# # Hyperparameters
# epochs = 100
# batch_size = 100
# learning_rate = 0.001
# decay = 1e-2
# validation_split = 0.2
# neurons = 150
# LD1=128
# LD2=128
# LD3=64
# LD4=64
# LD5=32
# LD6=16
# LD7=5

# %%
# start_time = time.time()

# # Create PyTorch datasets and dataloaders
# train_dataset = TensorDataset(x_train_scaled_test, y_train_scaled_test)
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

# # Build the model
# model = nn.Sequential(
#     nn.Linear(x_test_1_scaled.shape[1], LD1),
#     nn.ReLU(),
#     nn.Linear(LD1, LD2),
#     nn.ReLU(),
#     nn.Linear(LD2, LD3),
#     nn.ReLU(),
#     nn.Linear(LD3, LD4),
#     nn.ReLU(),
#     nn.Linear(LD4, LD5),
#     nn.ReLU(),
#     nn.Linear(LD5, LD6),
#     nn.ReLU(),
#     nn.Linear(LD6, 1)
# ).to(device)

# # Define loss and optimizer
# criterion = nn.MSELoss()
# optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# # Training loop
# for epoch in range(epochs):
#     total_loss = 0.0
#     for inputs, labels in train_loader:
#         inputs, labels = inputs.to(device), labels.to(device)
#         optimizer.zero_grad()
#         outputs = model(inputs)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()
#         total_loss += loss.item()
#     print(f"Epoch {epoch + 1}/{epochs}, Loss: {total_loss / len(train_loader)}")
# print('finish')
# print("Run Time:" + " %s seconds " % (time.time() - start_time))
# #save model
# #torch.save(model.state_dict(), f"./mlp_models/mlp_model.pkl")

# %%
# # Build and load the model
device = torch.device('cpu') # for some reason had to change to cpu
models = nn.Sequential(
    nn.Linear(x_test_1_scaled.shape[1], LD1),
    nn.ReLU(),
    nn.Linear(LD1, LD2),
    nn.ReLU(),
    nn.Linear(LD2, LD3),
    nn.ReLU(),
    nn.Linear(LD3, LD4),
    nn.ReLU(),
    nn.Linear(LD4, LD5),
    nn.ReLU(),
    nn.Linear(LD5, LD6),
    nn.ReLU(),
    nn.Linear(LD6, 1)
).to(device)

models.load_state_dict(torch.load(f"{path_01}03.output/mlp/mlp_model.pkl", map_location=torch.device('cpu')))

EvalDF = pd.DataFrame(columns = cols)
SupplyEvalDF = pd.DataFrame(columns = supcols)

SitesDict = {}

for station_number in station_index_list.drop_duplicates():
    index = station_index_list == station_number # Finind the rows that have this station number.
    X_test_scaled = torch.Tensor(x_test_1_scaled[index])
    
    # Evaluation
    models.eval()
    with torch.no_grad():
        yhat_test= models(X_test_scaled)

    # Invert scaling for actual
    inv_yhat_test = scaler.inverse_transform(yhat_test.numpy())
    inv_yhat_test[inv_yhat_test<0] = 0 # THIS IS NOT CORRECT !!!!!!!!!!!!!!!
    nwm_test = pd.DataFrame(inv_yhat_test, columns=['MLP_flow'])
    Dfs = [nwm_test.reset_index(drop=True), x_test_temp[index].reset_index(drop=True)]

    #get reach id for model eval
    nhdreach = utils.crosswalk(usgs_site_codes=station_number)
    nhdreach = nhdreach['nwm_feature_id'].iloc[0]
    
    #save predictions
    mod = 'MLP'
    save_path = f"./Predictions/Hindcast/{mod}/{mod}_{nhdreach}.csv"
    #nwm_test.to_csv(save_path)
    
    # merge
    Eval_DF_mine = pd.concat(Dfs, axis=1)
    SitesDict[nhdreach] = Eval_DF_mine

    
    prediction_columns = ['NWM_flow', 'MLP_flow']
    observation_column = 'flow_cfs'
    
    #Get RMSE from the model
    rmse = RMSE(Eval_DF_mine, prediction_columns, observation_column)

    #Get Mean Absolute Percentage Error from the model
    mape = MAPE(Eval_DF_mine, prediction_columns, observation_column)

    #Get Percent Bias from the model
    pbias = PBias(Eval_DF_mine, prediction_columns, observation_column)

    #Get Kling-Gutz Efficiency from the model
    kge = KGE(Eval_DF_mine, prediction_columns, observation_column)
    
    #Get Volumetric values
    Eval_DF_mine.set_index('datetime', inplace = True, drop =True)
    flowcols = [f"{mod}_flow", 'flow_cfs', 'NWM_flow']
    SupplyEval = Eval_DF_mine[flowcols].copy()
    SupplyEval = SupplyEval*cfsday_AFday
    #set up cumulative monthly values
    SupplyEval['Year'] = SupplyEval.index.year

    for site in flowcols:
        SupplyEval[site] = SupplyEval.groupby(['Year'])[site].cumsum()  

    EOY_mod_vol_af = SupplyEval[f"{mod}_flow"].iloc[-1]
    EOY_obs_vol_af = SupplyEval["flow_cfs"].iloc[-1]
    EOY_nwm_vol_af = SupplyEval[f"NWM_flow"].iloc[-1]
    NWM_vol_diff_af = EOY_nwm_vol_af - EOY_obs_vol_af
    Mod_vol_diff_af = EOY_mod_vol_af - EOY_obs_vol_af
    NWM_Perc_diff = (NWM_vol_diff_af/EOY_obs_vol_af)*100
    Mod_Perc_diff = (Mod_vol_diff_af/EOY_obs_vol_af)*100
    
     #Get Performance Metrics from the model
    Srmse = RMSE(SupplyEval, prediction_columns, observation_column)
    Smape = MAPE(SupplyEval, prediction_columns, observation_column)
    Spbias = PBias(SupplyEval, prediction_columns, observation_column)
    Skge = KGE(SupplyEval, prediction_columns, observation_column)
    
    
    #save model performance
    sitestats = [station_number, nhdreach, rmse[0], rmse[1],  pbias[0], pbias[1], kge[0], kge[1], mape[0],mape[1]]
    EvalDF.loc[len(EvalDF)] = sitestats
    
    Supplystats = [station_number, nhdreach, Srmse[0], Srmse[1],  Spbias[0], Spbias[1], Skge[0], Skge[1], Smape[0],  
                 Smape[1],EOY_obs_vol_af, EOY_nwm_vol_af,EOY_mod_vol_af,NWM_vol_diff_af,Mod_vol_diff_af, NWM_Perc_diff, Mod_Perc_diff ]
    SupplyEvalDF.loc[len(SupplyEvalDF)] = Supplystats
    
    
    
    
    #put prediction DF into dictionary
    # Eval_DF_mine.reset_index(inplace = True)
    # Eval_DF_mine.sort_values(by=['datetime'], inplace=True)
    # Eval_DF_mine.set_index('datetime', inplace = True)
    
    
    
#save model results
#EvalDF.to_csv(f"./Predictions/Hindcast/{mod}/{mod}_Performance.csv")   
#SupplyEvalDF.to_csv(f"./Predictions/Hindcast/{mod}/{mod}_Supply_Performance.csv")

print('finish')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 75
#      72 observation_column = 'flow_cfs'
#      74 #Get RMSE from the model
# ---> 75 rmse = RMSE(Eval_DF_mine, prediction_columns, observation_column)
#      77 #Get Mean Absolute Percentage Error from the model
#      78 mape = MAPE(Eval_DF_mine, prediction_columns, observation_column)
#
# NameError: name 'RMSE' is not defined

# %%
# MODEL CLASS
import torch
import torch.nn as nn
import torch.optim as optim

class CustomMLP(nn.Module):
    def __init__(self, layer_sizes, device=None):
        super(CustomMLP, self).__init__()
        self.layers = nn.ModuleList()
        for i in range(len(layer_sizes) - 1):
            self.layers.append(nn.Linear(layer_sizes[i], layer_sizes[i + 1]))
        self.loss_function = nn.MSELoss()
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu") if device is None else device
        self.to(self.device)
        self.validation_indicator = 0

    def forward(self, x):
        for i in range(len(self.layers) - 1):
            x = torch.relu(self.layers[i](x))
        x = self.layers[-1](x)
        return x

    def train_model(self, train_loader, epochs, early_stopping_patience, learning_rate=None, save_path=None, val_loader=None):
        best_val_loss = float('inf')
        epochs_no_improve = 0
        optimizer = optim.Adam(self.layers.parameters(), lr=learning_rate)

        for epoch in range(epochs):
            self.train()  # Set the model to training mode
            for inputs, targets in train_loader:
                inputs, targets = inputs.to(self.device), targets.to(self.device)

                optimizer.zero_grad()
                outputs = self.forward(inputs)
                loss = self.loss_function(outputs, targets)
                loss.backward()
                optimizer.step()

            
            val_loss = 0
            if val_loader is not None:
                self.validation_indicator = 1
                val_loss = self.evaluate_model(val_loader)

                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    torch.save(self.state_dict(), save_path)
                    epochs_no_improve = 0
                else:
                    epochs_no_improve += 1

                # if epochs_no_improve == early_stopping_patience:
                #     print('Early stopping triggered')
                #     break
            print(f'Epoch {epoch+1}/{epochs}, Training Loss: {loss.item()}', f'Validation Loss: {val_loss}')
        self.validation_indicator = 0
        print('Training is done!')

    def evaluate_model(self, data_loader):
        self.eval()  # Set the model to evaluation mode
        total_loss = 0
        total = 0
        with torch.no_grad():
            for inputs, targets in data_loader:
                inputs, targets = inputs.to(self.device), targets.to(self.device)

                outputs = self.forward(inputs)
                loss = self.loss_function(outputs, targets)
                total_loss += loss.item() * inputs.size(0)
                total += inputs.size(0)
        avg_loss = total_loss / total
        if self.validation_indicator == 0:
            print(f'Validation Loss: {avg_loss}')
        return outputs if self.validation_indicator == 0 else avg_loss

    def save_model(self, file_path):
        torch.save(self.state_dict(), file_path)

    def load_model(self, file_path):
        self.load_state_dict(torch.load(file_path, map_location=self.device))

# Example Usage:
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model = CustomMLP(layer_sizes, learning_rate=0.01, device=device)
# model.train_model(train_loader, epochs=5, val_loader=val_loader, early_stopping_patience=5, save_path='best_model.pth')
# model.load_model('best_model.pth')

# %%
# I should modify the model evauation and testing part.

# %%
# %load_ext autoreload
# %autoreload 2
mod='MLP'
epochs = 200
batch_size = 100
learning_rate = 0.001
early_stopping_patience=5
decay = 1e-2
path_model_parameters = f"{path_01}03.output/best_model.pkl"
#path_01 + '03.output/best_model.pkl'
layer_sizes = [x_train_scaled_test.shape[1] ,128, 128, 64, 64, 32, 16, 5, 1]
# neurons = 150
# LD1=128
# LD2=128
# LD3=64
# LD4=64
# LD5=32
# LD6=16
# LD7=5
# validation_split = 0.2

# I should add decay

# %%
# Create PyTorch datasets and dataloaders

#X_train, X_valid, y_train, y_valid = train_test_split(x_train_scaled_test, y_train_scaled_test)

train_dataset = TensorDataset(x_train_scaled_test, y_train_scaled_test)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
# validation_dataset = TensorDataset(X_valid, y_valid)
# validation_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)

# %%
mlp_model = CustomMLP(layer_sizes, device)

# %%
mlp_model.train_model(train_loader, epochs, early_stopping_patience, learning_rate, path_model_parameters)
# Out:
# Epoch 1/200, Training Loss: 0.0003272944886703044 Validation Loss: 0
# Epoch 2/200, Training Loss: 0.00017656754062045366 Validation Loss: 0
# Epoch 3/200, Training Loss: 0.0002624697226565331 Validation Loss: 0
# Epoch 4/200, Training Loss: 0.0003445963084232062 Validation Loss: 0
# Epoch 5/200, Training Loss: 0.0003139563777949661 Validation Loss: 0
# Epoch 6/200, Training Loss: 0.0005090840859338641 Validation Loss: 0
# Epoch 7/200, Training Loss: 0.0008741760393604636 Validation Loss: 0
# Epoch 8/200, Training Loss: 0.0011440437519922853 Validation Loss: 0
# Epoch 9/200, Training Loss: 0.001751930103637278 Validation Loss: 0
# Epoch 10/200, Training Loss: 0.0005906976293772459 Validation Loss: 0
# Epoch 11/200, Training Loss: 0.000531708647031337 Validation Loss: 0
# Epoch 12/200, Training Loss: 0.0008743303478695452 Validation Loss: 0
# Epoch 13/200, Training Loss: 0.0009528466034680605 Validation Loss: 0
# Epoch 14/200, Training Loss: 0.0003838026023004204 Validation Loss: 0
# Epoch 15/200, Training Loss: 0.000568421499338001 Validation Loss: 0
# Epoch 16/200, Training Loss: 0.00016761534789111465 Validation Loss: 0
# Epoch 17/200, Training Loss: 0.00014603245654143393 Validation Loss: 0
# Epoch 18/200, Training Loss: 0.00014375016326084733 Validation Loss: 0
# Epoch 19/200, Training Loss: 0.0001527377899037674 Validation Loss: 0
# Epoch 20/200, Training Loss: 0.00018505669140722603 Validation Loss: 0
# Epoch 21/200, Training Loss: 0.0002237129956483841 Validation Loss: 0
# Epoch 22/200, Training Loss: 0.0002083694125758484 Validation Loss: 0
# Epoch 23/200, Training Loss: 0.0003198719641659409 Validation Loss: 0
# Epoch 24/200, Training Loss: 0.00019882967171724886 Validation Loss: 0
# Epoch 25/200, Training Loss: 0.00027928908821195364 Validation Loss: 0
# Epoch 26/200, Training Loss: 0.0004947613924741745 Validation Loss: 0
# Epoch 27/200, Training Loss: 0.00021873487276025116 Validation Loss: 0
# Epoch 28/200, Training Loss: 0.0001346520584775135 Validation Loss: 0
# Epoch 29/200, Training Loss: 0.0001654208463151008 Validation Loss: 0
# Epoch 30/200, Training Loss: 0.0002533249498810619 Validation Loss: 0
# Epoch 31/200, Training Loss: 0.00041631085332483053 Validation Loss: 0
# Epoch 32/200, Training Loss: 0.000548684794921428 Validation Loss: 0
# Epoch 33/200, Training Loss: 0.00023669294023420662 Validation Loss: 0
# Epoch 34/200, Training Loss: 0.0004082816303707659 Validation Loss: 0
# Epoch 35/200, Training Loss: 0.0003042173630092293 Validation Loss: 0
# Epoch 36/200, Training Loss: 0.00031515181763097644 Validation Loss: 0
# Epoch 37/200, Training Loss: 0.00026063452241942286 Validation Loss: 0
# Epoch 38/200, Training Loss: 0.00031977175967767835 Validation Loss: 0
# Epoch 39/200, Training Loss: 0.00018729448493104428 Validation Loss: 0
# Epoch 40/200, Training Loss: 0.00012934263213537633 Validation Loss: 0
# Epoch 41/200, Training Loss: 0.00018767551227938384 Validation Loss: 0
# Epoch 42/200, Training Loss: 0.0001440337218809873 Validation Loss: 0
# Epoch 43/200, Training Loss: 0.00022461017942987382 Validation Loss: 0
# Epoch 44/200, Training Loss: 0.000181432202225551 Validation Loss: 0
# Epoch 45/200, Training Loss: 0.00011692332191159949 Validation Loss: 0
# Epoch 46/200, Training Loss: 0.00010913668666034937 Validation Loss: 0
# Epoch 47/200, Training Loss: 0.00011652444663923234 Validation Loss: 0
# Epoch 48/200, Training Loss: 0.00012053376849507913 Validation Loss: 0
# Epoch 49/200, Training Loss: 0.00011794138117693365 Validation Loss: 0
# Epoch 50/200, Training Loss: 0.0001674779923632741 Validation Loss: 0
# Epoch 51/200, Training Loss: 0.00011065319267800078 Validation Loss: 0
# Epoch 52/200, Training Loss: 0.00011633307440206409 Validation Loss: 0
# Epoch 53/200, Training Loss: 0.00014661585737485439 Validation Loss: 0
# Epoch 54/200, Training Loss: 0.000145537662319839 Validation Loss: 0
# Epoch 55/200, Training Loss: 0.0001973341713892296 Validation Loss: 0
# Epoch 56/200, Training Loss: 0.00019698859250638634 Validation Loss: 0
# Epoch 57/200, Training Loss: 0.00027400371618568897 Validation Loss: 0
# Epoch 58/200, Training Loss: 0.00012925030023325235 Validation Loss: 0
# Epoch 59/200, Training Loss: 0.0015409898478537798 Validation Loss: 0
# Epoch 60/200, Training Loss: 0.0004635981749743223 Validation Loss: 0
# Epoch 61/200, Training Loss: 0.0008904190035536885 Validation Loss: 0
# Epoch 62/200, Training Loss: 0.00010154207120649517 Validation Loss: 0
# Epoch 63/200, Training Loss: 0.00019857703591696918 Validation Loss: 0
# Epoch 64/200, Training Loss: 0.00026406210963614285 Validation Loss: 0
# Epoch 65/200, Training Loss: 0.00016652797057759017 Validation Loss: 0
# Epoch 66/200, Training Loss: 0.00018786336295306683 Validation Loss: 0
# Epoch 67/200, Training Loss: 0.00011374107998562977 Validation Loss: 0
# Epoch 68/200, Training Loss: 0.00016665297152940184 Validation Loss: 0
# Epoch 69/200, Training Loss: 0.00012650672579184175 Validation Loss: 0
# Epoch 70/200, Training Loss: 0.00010875217412831262 Validation Loss: 0
# Epoch 71/200, Training Loss: 0.00010854373249458149 Validation Loss: 0
# Epoch 72/200, Training Loss: 0.00015631057613063604 Validation Loss: 0
# Epoch 73/200, Training Loss: 0.0001162516709882766 Validation Loss: 0
# Epoch 74/200, Training Loss: 0.0001075052423402667 Validation Loss: 0
# Epoch 75/200, Training Loss: 0.00010960827057715505 Validation Loss: 0
# Epoch 76/200, Training Loss: 0.00012029884965158999 Validation Loss: 0
# Epoch 77/200, Training Loss: 0.00010542693780735135 Validation Loss: 0
# Epoch 78/200, Training Loss: 0.00012517582217697054 Validation Loss: 0
# Epoch 79/200, Training Loss: 0.0001622841227799654 Validation Loss: 0
# Epoch 80/200, Training Loss: 0.00012377681559883058 Validation Loss: 0
# Epoch 81/200, Training Loss: 0.0001740291918395087 Validation Loss: 0
# Epoch 82/200, Training Loss: 0.00012362613051664084 Validation Loss: 0
# Epoch 83/200, Training Loss: 0.00011894055205630139 Validation Loss: 0
# Epoch 84/200, Training Loss: 0.0002158354182029143 Validation Loss: 0
# Epoch 85/200, Training Loss: 0.00014812931476626545 Validation Loss: 0
# Epoch 86/200, Training Loss: 0.00014106590242590755 Validation Loss: 0
# Epoch 87/200, Training Loss: 0.0001300630101468414 Validation Loss: 0
# Epoch 88/200, Training Loss: 0.00011371880100341514 Validation Loss: 0
# Epoch 89/200, Training Loss: 0.00011031988833565265 Validation Loss: 0
# Epoch 90/200, Training Loss: 0.00010606772411847487 Validation Loss: 0
# Epoch 91/200, Training Loss: 0.00020143108849879354 Validation Loss: 0
# Epoch 92/200, Training Loss: 0.00014094873040448874 Validation Loss: 0
# Epoch 93/200, Training Loss: 0.00018499320140108466 Validation Loss: 0
# Epoch 94/200, Training Loss: 0.00014040080714039505 Validation Loss: 0
# Epoch 95/200, Training Loss: 0.00018044472381006926 Validation Loss: 0
# Epoch 96/200, Training Loss: 0.00011584284948185086 Validation Loss: 0
# Epoch 97/200, Training Loss: 0.00014929585449863225 Validation Loss: 0
# Epoch 98/200, Training Loss: 0.00018298513896297663 Validation Loss: 0
# Epoch 99/200, Training Loss: 0.00011065088619943708 Validation Loss: 0
# Epoch 100/200, Training Loss: 0.00024124425544869155 Validation Loss: 0
# Epoch 101/200, Training Loss: 0.00014025172276888043 Validation Loss: 0
# Epoch 102/200, Training Loss: 0.00020268360094632953 Validation Loss: 0
# Epoch 103/200, Training Loss: 0.00014699672465212643 Validation Loss: 0
# Epoch 104/200, Training Loss: 0.00012955359125044197 Validation Loss: 0
# Epoch 105/200, Training Loss: 0.00010668065078789368 Validation Loss: 0
# Epoch 106/200, Training Loss: 0.00010815688438015059 Validation Loss: 0
# Epoch 107/200, Training Loss: 0.0001462399523006752 Validation Loss: 0
# Epoch 108/200, Training Loss: 0.00018618369358591735 Validation Loss: 0
# Epoch 109/200, Training Loss: 0.0001693138328846544 Validation Loss: 0
# Epoch 110/200, Training Loss: 0.00015604107466060668 Validation Loss: 0
# Epoch 111/200, Training Loss: 0.0002137552946805954 Validation Loss: 0
# Epoch 112/200, Training Loss: 0.0001705498871160671 Validation Loss: 0
# Epoch 113/200, Training Loss: 0.00023919813975226134 Validation Loss: 0
# Epoch 114/200, Training Loss: 0.00018657643522601575 Validation Loss: 0
# Epoch 115/200, Training Loss: 0.00011642894241958857 Validation Loss: 0
# Epoch 116/200, Training Loss: 0.00015287169662769884 Validation Loss: 0
# Epoch 117/200, Training Loss: 0.00012458469427656382 Validation Loss: 0
# Epoch 118/200, Training Loss: 0.00011623051977949217 Validation Loss: 0
# Epoch 119/200, Training Loss: 0.00011621005251072347 Validation Loss: 0
# Epoch 120/200, Training Loss: 0.00016633604536764324 Validation Loss: 0
# Epoch 121/200, Training Loss: 0.00011515426012920216 Validation Loss: 0
# Epoch 122/200, Training Loss: 0.00011051732872147113 Validation Loss: 0
# Epoch 123/200, Training Loss: 0.00012984994100406766 Validation Loss: 0
# Epoch 124/200, Training Loss: 0.00020036606292705983 Validation Loss: 0
# Epoch 125/200, Training Loss: 0.00012195394810987636 Validation Loss: 0
# Epoch 126/200, Training Loss: 0.00014124410517979413 Validation Loss: 0
# Epoch 127/200, Training Loss: 0.00013550871517509222 Validation Loss: 0
# Epoch 128/200, Training Loss: 0.00010922038927674294 Validation Loss: 0
# Epoch 129/200, Training Loss: 0.00011771397839765996 Validation Loss: 0
# Epoch 130/200, Training Loss: 0.00012148604582762346 Validation Loss: 0
# Epoch 131/200, Training Loss: 0.000132130560814403 Validation Loss: 0
# Epoch 132/200, Training Loss: 0.00010745612235041335 Validation Loss: 0
# Epoch 133/200, Training Loss: 7.491789438063279e-05 Validation Loss: 0
# Epoch 134/200, Training Loss: 0.00013874727301299572 Validation Loss: 0
# Epoch 135/200, Training Loss: 0.0001046904144459404 Validation Loss: 0
# Epoch 136/200, Training Loss: 9.401818533660844e-05 Validation Loss: 0
# Epoch 137/200, Training Loss: 8.632249955553561e-05 Validation Loss: 0
# Epoch 138/200, Training Loss: 8.022804104257375e-05 Validation Loss: 0
# Epoch 139/200, Training Loss: 5.674636486219242e-05 Validation Loss: 0
# Epoch 140/200, Training Loss: 7.612951594637707e-05 Validation Loss: 0
# Epoch 141/200, Training Loss: 0.00010301334987161681 Validation Loss: 0
# Epoch 142/200, Training Loss: 9.0266257757321e-05 Validation Loss: 0
# Epoch 143/200, Training Loss: 8.806944970274344e-05 Validation Loss: 0
# Epoch 144/200, Training Loss: 9.061767195817083e-05 Validation Loss: 0
# Epoch 145/200, Training Loss: 0.00018023607844952494 Validation Loss: 0
# Epoch 146/200, Training Loss: 9.230002615367994e-05 Validation Loss: 0
# Epoch 147/200, Training Loss: 9.673961903899908e-05 Validation Loss: 0
# Epoch 148/200, Training Loss: 9.352120832772925e-05 Validation Loss: 0
# Epoch 149/200, Training Loss: 0.0001286196056753397 Validation Loss: 0
# Epoch 150/200, Training Loss: 8.983754378277808e-05 Validation Loss: 0
# Epoch 151/200, Training Loss: 7.032527355477214e-05 Validation Loss: 0
# Epoch 152/200, Training Loss: 6.484445475507528e-05 Validation Loss: 0
# Epoch 153/200, Training Loss: 8.320574852405116e-05 Validation Loss: 0
# Epoch 154/200, Training Loss: 0.00022806409106124192 Validation Loss: 0
# Epoch 155/200, Training Loss: 5.0793598347809166e-05 Validation Loss: 0
# Epoch 156/200, Training Loss: 8.979659469332546e-05 Validation Loss: 0
# Epoch 157/200, Training Loss: 0.0001044539749273099 Validation Loss: 0
# Epoch 158/200, Training Loss: 0.00010099607607116923 Validation Loss: 0
# Epoch 159/200, Training Loss: 0.00014119829575065523 Validation Loss: 0
# Epoch 160/200, Training Loss: 0.0001016695678117685 Validation Loss: 0
# Epoch 161/200, Training Loss: 5.786275869468227e-05 Validation Loss: 0
# Epoch 162/200, Training Loss: 0.00010165435378439724 Validation Loss: 0
# Epoch 163/200, Training Loss: 0.00011911208275705576 Validation Loss: 0
# Epoch 164/200, Training Loss: 0.00016672935453243554 Validation Loss: 0
# Epoch 165/200, Training Loss: 0.00028510470292530954 Validation Loss: 0
# Epoch 166/200, Training Loss: 0.00010888571705436334 Validation Loss: 0
# Epoch 167/200, Training Loss: 8.642573811812326e-05 Validation Loss: 0
# Epoch 168/200, Training Loss: 8.620908192824572e-05 Validation Loss: 0
# Epoch 169/200, Training Loss: 5.313467045198195e-05 Validation Loss: 0
# Epoch 170/200, Training Loss: 0.00017234038386959583 Validation Loss: 0
# Epoch 171/200, Training Loss: 0.00010904920054599643 Validation Loss: 0
# Epoch 172/200, Training Loss: 8.93150208867155e-05 Validation Loss: 0
# Epoch 173/200, Training Loss: 0.00016688978939782828 Validation Loss: 0
# Epoch 174/200, Training Loss: 0.00014461764658335596 Validation Loss: 0
# Epoch 175/200, Training Loss: 7.302465382963419e-05 Validation Loss: 0
# Epoch 176/200, Training Loss: 9.831251372816041e-05 Validation Loss: 0
# Epoch 177/200, Training Loss: 0.0003419135755393654 Validation Loss: 0
# Epoch 178/200, Training Loss: 7.104512042133138e-05 Validation Loss: 0
# Epoch 179/200, Training Loss: 7.206934969872236e-05 Validation Loss: 0
# Epoch 180/200, Training Loss: 9.446575859328732e-05 Validation Loss: 0
# Epoch 181/200, Training Loss: 5.440352106234059e-05 Validation Loss: 0
# Epoch 182/200, Training Loss: 0.0001789262896636501 Validation Loss: 0
# Epoch 183/200, Training Loss: 0.00016590897575952113 Validation Loss: 0
# Epoch 184/200, Training Loss: 7.621329859830439e-05 Validation Loss: 0
# Epoch 185/200, Training Loss: 6.864627357572317e-05 Validation Loss: 0
# Epoch 186/200, Training Loss: 6.589335680473596e-05 Validation Loss: 0
# Epoch 187/200, Training Loss: 5.984858944430016e-05 Validation Loss: 0
# Epoch 188/200, Training Loss: 7.048066618153825e-05 Validation Loss: 0

# %%
mlp_model.load_model(path_model_parameters)

# %%
from evalaution_table import evtab

EvalDF = np.zeros([len(station_index_list.drop_duplicates()), 10])
SupplyEvalDF = np.zeros([len(station_index_list.drop_duplicates()), 17])

SitesDict = {}



for station_index, station_number in enumerate(station_index_list.drop_duplicates()):
    index = station_index_list == station_number # Finind the rows that have this station number.
    temp_x_scaled_test = torch.Tensor(x_test_1_scaled)
    temp_y_scaled_test = torch.Tensor(y_scaled_test_1)
    index_np = torch.tensor(index.to_numpy())

    test_dataset = TensorDataset(temp_x_scaled_test[index_np], temp_y_scaled_test[index_np])
    test_loader = DataLoader(test_dataset, batch_size=test_dataset.tensors[0].shape[0], shuffle=False)
    
    # Evaluation
    yhat_test = mlp_model.evaluate_model(test_loader)
    
    # Invert scaling for actual
    inv_yhat_test = scaler.inverse_transform(yhat_test.numpy())
    inv_yhat_test[inv_yhat_test<0] = 0 # THIS IS NOT CORRECT !!!!!!!!!!!!!!!
    nwm_test = pd.DataFrame(inv_yhat_test, columns=['MLP_flow'])
    Dfs = [nwm_test.reset_index(drop=True), x_test_temp[index].reset_index(drop=True)]

    #get reach id for model eval
    nhdreach = utils.crosswalk(usgs_site_codes=station_number)
    nhdreach = nhdreach['nwm_feature_id'].iloc[0]
    
    #save predictions
    #save_path = f"./Predictions/Hindcast/{mod}/{mod}_{nhdreach}.csv"
    #nwm_test.to_csv(save_path)
    
    # merge
    Eval_DF_mine = pd.concat(Dfs, axis=1)
    SitesDict[nhdreach] = Eval_DF_mine
    prediction_columns = ['NWM_flow', f"{mod}_flow"]
    observation_column = 'flow_cfs'
    result = evtab(Eval_DF_mine, prediction_columns, nhdreach, observation_column, mod)
    
    #save model performance
    EvalDF[station_index, :] = result[0]
    SupplyEvalDF[station_index, :] = result[1]
    
    

print('finish')
# Out:
# Validation Loss: 0.017544051632285118
# Validation Loss: 0.0018668673001229763
# Validation Loss: 0.0007869558758102357
# Validation Loss: 0.003422613488510251
# Validation Loss: 0.00023849683930166066
# Validation Loss: 0.0036304083187133074
# Validation Loss: 0.0017385041574016213
# Validation Loss: 6.514557026093826e-05
# Validation Loss: 0.00010211471089860424
# finish

# %%
from evalaution_table import evtab
# # Build and load the model
device = torch.device('cpu') # for some reason had to change to cpu
models = nn.Sequential(
    nn.Linear(x_test_1_scaled.shape[1], LD1),
    nn.ReLU(),
    nn.Linear(LD1, LD2),
    nn.ReLU(),
    nn.Linear(LD2, LD3),
    nn.ReLU(),
    nn.Linear(LD3, LD4),
    nn.ReLU(),
    nn.Linear(LD4, LD5),
    nn.ReLU(),
    nn.Linear(LD5, LD6),
    nn.ReLU(),
    nn.Linear(LD6, 1)
).to(device)

models.load_state_dict(torch.load(f"{path_01}03.output/mlp/mlp_model.pkl", map_location=torch.device('cpu')))

EvalDF = np.zeros([len(tation_index_list.drop_duplicates()), 10])
SupplyEvalDF = np.zeros([len(tation_index_list.drop_duplicates()), 10])

SitesDict = {}

for station_index, station_number in enumerate(station_index_list.drop_duplicates()):
    index = station_index_list == station_number # Finind the rows that have this station number.
    X_test_scaled = torch.Tensor(x_test_1_scaled[index])
    
    # Evaluation
    models.eval()
    with torch.no_grad():
        yhat_test= models(X_test_scaled)

    # Invert scaling for actual
    inv_yhat_test = scaler.inverse_transform(yhat_test.numpy())
    inv_yhat_test[inv_yhat_test<0] = 0 # THIS IS NOT CORRECT !!!!!!!!!!!!!!!
    nwm_test = pd.DataFrame(inv_yhat_test, columns=['MLP_flow'])
    Dfs = [nwm_test.reset_index(drop=True), x_test_temp[index].reset_index(drop=True)]

    #get reach id for model eval
    nhdreach = utils.crosswalk(usgs_site_codes=station_number)
    nhdreach = nhdreach['nwm_feature_id'].iloc[0]
    
    #save predictions
    save_path = f"./Predictions/Hindcast/{mod}/{mod}_{nhdreach}.csv"
    #nwm_test.to_csv(save_path)
    
    # merge
    Eval_DF_mine = pd.concat(Dfs, axis=1)
    SitesDict[nhdreach] = Eval_DF_mine
    prediction_columns = ['NWM_flow', f"{mod}_flow"]
    observation_column = 'flow_cfs'
    result = evtab(Eval_DF_mine, prediction_columns, nhdreach, observation_column, mod)
    
    #save model performance
    EvalDF[station_index, :] = temp[0]
    SupplyEvalDF[station_index, :] = temp[1]
    
    

print('finish')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 5
#       2 # # Build and load the model
#       3 device = torch.device('cpu') # for some reason had to change to cpu
#       4 models = nn.Sequential(
# ----> 5     nn.Linear(x_test_1_scaled.shape[1], LD1),
#       6     nn.ReLU(),
#       7     nn.Linear(LD1, LD2),
#       8     nn.ReLU(),
#       9     nn.Linear(LD2, LD3),
#      10     nn.ReLU(),
#      11     nn.Linear(LD3, LD4),
#      12     nn.ReLU(),
#      13     nn.Linear(LD4, LD5),
#      14     nn.ReLU(),
#      15     nn.Linear(LD5, LD6),
#      16     nn.ReLU(),
#      17     nn.Linear(LD6, 1)
#      18 ).to(device)
#      20 models.load_state_dict(torch.load(f"{path_01}03.output/mlp/mlp_model.pkl", map_location=torch.device('cpu')))
#      22 EvalDF = np.zeros([len(tation_index_list.drop_duplicates()), 10])
#
# NameError: name 'LD1' is not defined

# %%
#put the model scores into a dataframe for comparison
mod = 'MLP'
#Evaluation columns for prediction time series
cols = ['USGSid', 'NHDPlusid', 'NWM_rmse', f"{mod}_rmse", 'NWM_pbias', f"{mod}_pbias", 
        'NWM_kge', f"{mod}__kge", 'NWM_mape',  f"{mod}_mape"]

#Evaluation columns for accumulated supply time series
supcols = ['USGSid', 'NHDPlusid', 'NWM_rmse', f"{mod}_rmse", 'NWM_pbias', f"{mod}_pbias", 
        'NWM_kge', f"{mod}__kge", 'NWM_mape',  f"{mod}_mape", 'Obs_vol', 'NWM_vol', f"{mod}_vol",
        'NWM_vol_err', f"{mod}_vol_err", 'NWM_vol_Perc_diff', f"{mod}_vol_Perc_diff"]
    
#save model results
EvalDF = pd.DataFrame(EvalDF, columns=cols)
SupplyEvalDF = pd.DataFrame(SupplyEvalDF, columns=supcols)

#EvalDF.to_csv(f"./Predictions/Hindcast/{mod}/{mod}_Performance.csv")   
#SupplyEvalDF.to_csv(f"./Predictions/Hindcast/{mod}/{mod}_Supply_Performance.csv")

# %%
# I should change EvalDf and SupplyEvalDF to numpy arrays and make class for the models

# %%
print("Model Performance for Daily cfs")
display(EvalDF)   
print("Model Performance for Daily Accumulated Supply (Acre-Feet)")
display(SupplyEvalDF )
# Out:
# Model Performance for Daily cfs
#        USGSid   NHDPlusid     NWM_rmse     MLP_rmse  NWM_pbias  MLP_pbias  \
# 0  10126000.0   4605050.0  1861.439475  1234.432885     -53.15     -22.42
# 1  10130500.0  10092262.0   305.608055   402.679246    -114.84    -175.75
# 2  10134500.0  10277268.0   128.603024   258.961610    -235.17    -308.14
# 3  10136500.0  10274616.0   776.608631   545.232159    -191.07     -56.79
# 4  10137500.0  10274270.0   107.073089   143.927524      33.05     -60.19
# 5  10141000.0  10273232.0  1317.964422   558.986476    -412.87      11.47
# 6  10155000.0  10373622.0   317.555275   388.588886      21.78     -29.70
# 7  10164500.0  10329013.0   110.840940    75.167216    -123.23    -115.93
# 8  10171000.0  10390290.0  3558.880086    94.177406   -2822.39     -55.65
#
#    NWM_kge  MLP__kge  NWM_mape  MLP_mape
# 0     0.14      0.41    369.37    134.79
# 1    -0.80     -1.47    197.11    227.44
# 2    -1.48     -4.31   1014.93    337.42
# 3    -0.99      0.04    436.46    139.09
# 4     0.48      0.24     38.66    147.01
# 5    -3.20     -0.55   1670.95    274.01
# 6     0.47      0.58    123.39    172.92
# 7    -0.95     -0.29    130.71    234.83
# 8   -29.81     -0.40   3342.15     74.10
# Model Performance for Daily Accumulated Supply (Acre-Feet)
#        USGSid   NHDPlusid      NWM_rmse       MLP_rmse  NWM_pbias  MLP_pbias  \
# 0  10126000.0   4605050.0  4.525278e+05  236242.629231     -55.72       0.40
# 1  10130500.0  10092262.0  8.536463e+04  109174.787262    -120.90    -149.20
# 2  10134500.0  10277268.0  4.845263e+04   69323.782046    -213.52    -274.96
# 3  10136500.0  10274616.0  2.959131e+05  131958.234031    -155.58     -33.35
# 4  10137500.0  10274270.0  2.529990e+04   43361.365904      38.01     -43.53
# 5  10141000.0  10273232.0  5.382548e+05  146544.905923    -363.73      36.95
# 6  10155000.0  10373622.0  6.066519e+04   60744.832700      31.76     -18.89
# 7  10164500.0  10329013.0  3.034985e+04   22616.275105    -140.03     -90.50
# 8  10171000.0  10390290.0  1.481821e+06   34446.708416   -2948.53     -60.84
#
#    NWM_kge  MLP__kge  NWM_mape  MLP_mape        Obs_vol      NWM_vol  \
# 0     0.14      0.68     74.17     39.19  655183.188796  1149487.593
# 1    -0.72     -1.33    163.42    139.30   77596.594340   157380.795
# 2    -1.77     -3.31    521.08    247.84   37262.276058    96970.683
# 3    -0.86      0.44    243.69     92.56  172949.053345   490788.534
# 4     0.60      0.41     45.32    102.07   54744.014329    39350.652
# 5    -2.97     -0.01    977.87    121.10  120033.770763   685973.241
# 6     0.59      0.74     38.25     41.79  181010.801007   126493.587
# 7    -0.63     -0.06    183.25    121.79   19609.368842    59842.974
# 8   -38.73      0.06   3366.51     55.79   81024.872027  1912801.800
#
#          MLP_vol   NWM_vol_err    MLP_vol_err  NWM_vol_Perc_diff  \
# 0  946119.000000  4.943044e+05  290935.811204          75.445221
# 1  239854.406250  7.978420e+04  162257.811910         102.819204
# 2  136174.796875  5.970841e+04   98912.520817         160.238217
# 3  345694.218750  3.178395e+05  172745.165405         183.776363
# 4  118725.046875 -1.539336e+04   63981.032546         -28.118804
# 5  112689.867188  5.659395e+05   -7343.903575         471.483539
# 6  227690.281250 -5.451721e+04   46679.480243         -30.118210
# 7   59008.765625  4.023361e+04   39399.396783         205.175421
# 8   92719.296875  1.831777e+06   11694.424848        2260.758804
#
#    MLP_vol_Perc_diff
# 0          44.405262
# 1         209.104295
# 2         265.449487
# 3          99.882111
# 4         116.873111
# 5          -6.118198
# 6          25.788229
# 7         200.921290
# 8          14.433130

# %%
print("Model Performance for Daily cfs")
display(EvalDF)   
print("Model Performance for Daily Accumulated Supply (Acre-Feet)")
display(SupplyEvalDF )
# Out:
# Model Performance for Daily cfs
#      USGSid  NHDPlusid     NWM_rmse    MLP_rmse  NWM_pbias  MLP_pbias  \
# 0  10126000    4605050  1861.439475  692.033427     -53.15     -12.82
# 1  10130500   10092262   305.608055  120.717862    -114.84      20.07
# 2  10134500   10277268   128.603024   47.540663    -235.17      39.93
# 3  10136500   10274616   776.608631  216.496869    -191.07     -12.84
# 4  10137500   10274270   107.073089  137.583271      33.05      38.44
# 5  10141000   10273232  1317.964422  229.866345    -412.87      -8.40
# 6  10155000   10373622   317.555275  226.989005      21.78       2.64
# 7  10164500   10329013   110.840940   54.321582    -123.23      40.58
# 8  10171000   10390290  3558.880086   42.771226   -2822.39      -1.92
#
#    NWM_kge  MLP__kge  NWM_mape  MLP_mape
# 0     0.14      0.78    369.37     52.63
# 1    -0.80      0.24    197.11     70.01
# 2    -1.48      0.09   1014.93    170.26
# 3    -0.99      0.81    436.46     69.35
# 4     0.48      0.08     38.66     63.44
# 5    -3.20      0.85   1670.95     96.50
# 6     0.47      0.83    123.39     64.87
# 7    -0.95      0.06    130.71    120.70
# 8   -29.81     -0.09   3342.15     39.21
# Model Performance for Daily Accumulated Supply (Acre-Feet)
#      USGSid  NHDPlusid      NWM_rmse       MLP_rmse  NWM_pbias  MLP_pbias  \
# 0  10126000    4605050  4.525278e+05  135601.368137     -55.72     -11.09
# 1  10130500   10092262  8.536463e+04   18659.155726    -120.90      14.88
# 2  10134500   10277268  4.845263e+04    9943.377293    -213.52      33.60
# 3  10136500   10274616  2.959131e+05   21430.928363    -155.58     -10.09
# 4  10137500   10274270  2.529990e+04   41066.102563      38.01      46.02
# 5  10141000   10273232  5.382548e+05   25166.789448    -363.73      -9.14
# 6  10155000   10373622  6.066519e+04   27428.799109      31.76       2.28
# 7  10164500   10329013  3.034985e+04   14423.525165    -140.03      42.68
# 8  10171000   10390290  1.481821e+06    7273.459034   -2948.53       2.53
#
#    NWM_kge  MLP__kge  NWM_mape  MLP_mape        Obs_vol      NWM_vol  \
# 0     0.14      0.74     74.17     17.65  655183.188796  1149487.593
# 1    -0.72      0.61    163.42     40.42   77596.594340   157380.795
# 2    -1.77      0.38    521.08    110.20   37262.276058    96970.683
# 3    -0.86      0.89    243.69     29.58  172949.053345   490788.534
# 4     0.60      0.13     45.32     46.84   54744.014329    39350.652
# 5    -2.97      0.87    977.87     37.30  120033.770763   685973.241
# 6     0.59      0.83     38.25     33.34  181010.801007   126493.587
# 7    -0.63      0.13    183.25     78.26   19609.368842    59842.974
# 8   -38.73      0.94   3366.51     22.11   81024.872027  1912801.800
#
#          MLP_vol   NWM_vol_err    MLP_vol_err  NWM_vol_Perc_diff  \
# 0  767235.562500  4.943044e+05  112052.373704          75.445221
# 1   72287.570312  7.978420e+04   -5309.024027         102.819204
# 2   21517.763672  5.970841e+04  -15744.512386         160.238217
# 3  206140.578125  3.178395e+05   33191.524780         183.776363
# 4   47727.761719 -1.539336e+04   -7016.252611         -28.118804
# 5   75881.437500  5.659395e+05  -44152.333263         471.483539
# 6  167993.812500 -5.451721e+04  -13016.988507         -30.118210
# 7   16443.640625  4.023361e+04   -3165.728217         205.175421
# 8   65987.796875  1.831777e+06  -15037.075152        2260.758804
#
#    MLP_vol_Perc_diff
# 0          17.102449
# 1          -6.841826
# 2         -42.253222
# 3          19.191504
# 4         -12.816474
# 5         -36.783259
# 6          -7.191277
# 7         -16.143958
# 8         -18.558592

# %%
#save model results
EvalDF.to_csv(f"./Predictions/Hindcast/{mod}/{mod}_Performance.csv")

# %%
import importlib
importlib.reload(FigureGenerator)

# %%
import FigureGenerator

model = 'MLP'
plotname = 'MLP_TS_plot'
freq = 'D'
supply = True
title = 'Observed and Modeled flows for NHDPlus Reaches \n with Upstream Reservoirs in the Great Salt Lake Basin'
FigureGenerator.TS_plot(SitesDict, model, plotname, title, freq, supply)

# %%
plotname = 'MLP_ParityPlot'
FigureGenerator.Parity_plot(SitesDict, model, plotname)

# %%
import AWS_transfer
model = 'MLP'
state = 'ut'
AWS_transfer.Predictions2AWS(model, state)

# %%
reach = 10273232
variables =['NWM_flow', 'Obs_flow']
colors = ['blue', 'green']
model = 'MLP'
plotname = 'NWMFlow'
units = 'cfs'
y_lab = f"Flow ({units})"
title = f"Daily NWM Estimates \n Reach: {str(reach)}"


FigureGenerator.Var_TS_plot(SitesDict, reach, variables, colors, model,y_lab, plotname, title, units, supply = False)
